# %%
# !ls
# Out:
#  1.xml		      'search?type=book_info'
#  Compare_fastq.ipynb   unique_to_redclib_fibr.txt
#  domains_CDS.txt       unique_to_redclib_K562.txt
#  domains.txt	       unique_to_rnachrom_fibr.txt
#  formatted.xml	       unique_to_rnachrom_K562.txt
#  lengths.txt	       unstructured_acidic_basic.ipynb
#  npm_full.fasta        wget-log
#  panther_tree.xml      your_output_file.nwk

# %%
# !cut -f3,8 ../genomes.txt
# Out:
# cut: ../genomes.txt: No such file or directory
